# %% [markdown]
# # Learning SQL Programming
#
# A LinkedIn Learning course by [Scott Simpson](https://www.linkedin.com/learning/instructors/scott-simpson).

# %% [markdown]
# ## Setup

# %%
# Load SQL extension
# %load_ext sql

# %%
# Connect to the database
# %sql sqlite:///quizdata.db
# Out:
# 'Connected: @quizdata.db'

# %% [markdown]
# ## Challenges

# %% [markdown]
# ### Ask for Data from a Database

# %%
# %%sql
#
# /*
#  * List each person's name, team, and score
#  * List which prize each person wants and sort the list using that information
#  * Further sort the list by team name
# */
#
# SELECT shirt_or_hat, first_name, last_name, team, quiz_points
# FROM people
# ORDER BY shirt_or_hat, team;
# Out:
#  * sqlite:///quizdata.db
# Done.
# [('hat', 'Patrick', 'Johnson', 'Angry Ants', 71),
#  ('hat', 'Jonathan', 'Ryan', 'Angry Ants', 81),
#  ('hat', 'Michelle', 'Montgomery', 'Angry Ants', 76),
#  ('hat', 'Donna', 'Daniels', 'Angry Ants', 81),
#  ('hat', 'Darren', 'Ellis', 'Angry Ants', 84),
#  ('hat', 'Richard', 'Fox', 'Angry Ants', 74),
#  ('hat', 'Roy', 'Lopez', 'Angry Ants', 81),
#  ('hat', 'Raymond', 'Reyes', 'Angry Ants', 78),
#  ('hat', 'Anne', 'Ellis', 'Angry Ants', 79),
#  ('hat', 'Fred', 'Peters', 'Angry Ants', 88),
#  ('hat', 'James', 'Morrison', 'Angry Ants', 78),
#  ('hat', 'Richard', 'White', 'Angry Ants', 72),
#  ('hat', 'Doris', 'Cruz', 'Angry Ants', 75),
#  ('hat', 'Teresa', 'Oliver', 'Angry Ants', 79),
#  ('hat', 'Philip', 'Carr', 'Angry Ants', 84),
#  ('hat', 'Louise', 'Knight', 'Angry Ants', 83),
#  ('hat', 'Carol', 'Matthews', 'Angry Ants', 81),
#  ('hat', 'Annie', 'Greene', 'Angry Ants', 81),
#  ('hat', 'William', 'Richardson', 'Angry Ants', 76),
#  ('hat', 'Shirley', 'Green', 'Angry Ants', 80),
#  ('hat', 'Philip', 'Kim', 'Angry Ants', 79),
#  ('hat', 'Michael', 'Turner', 'Angry Ants', 75),
#  ('hat', 'Antonio', 'West', 'Angry Ants', 84),
#  ('hat', 'Jerry', 'Hawkins', 'Angry Ants', 77),
#  ('hat', 'Albert', 'Lawson', 'Angry Ants', 77),
#  ('hat', 'Debra', 'Scott', 'Angry Ants', 72),
#  ('hat', 'Eugene', 'Stewart', 'Angry Ants', 81),
#  ('hat', 'Kevin', 'Nguyen', 'Angry Ants', 70),
#  ('hat', 'Betty', 'Wilson', 'Angry Ants', 70),
#  ('hat', 'Sandra', 'Green', 'Angry Ants', 85),
#  ('hat', 'Gary', 'Young', 'Angry Ants', 82),
#  ('hat', 'Edward', 'Adams', 'Angry Ants', 78),
#  ('hat', 'Larry', 'Cruz', 'Angry Ants', 85),
#  ('hat', 'Peter', 'Nelson', 'Angry Ants', 76),
#  ('hat', 'Eugene', 'Jackson', 'Angry Ants', 79),
#  ('hat', 'Anna', 'Bryant', 'Angry Ants', 78),
#  ('hat', 'Jesse', 'Stone', 'Angry Ants', 74),
#  ('hat', 'Catherine', 'Dean', 'Angry Ants', 85),
#  ('hat', 'Doris', 'Lane', 'Angry Ants', 78),
#  ('hat', 'Marilyn', 'Davis', 'Angry Ants', 80),
#  ('hat', 'Ruth', 'Warren', 'Angry Ants', 77),
#  ('hat', 'Susan', 'Welch', 'Angry Ants', 81),
#  ('hat', 'Gregory', 'Fields', 'Angry Ants', 86),
#  ('hat', 'Stephen', 'Carter', 'Angry Ants', 79),
#  ('hat', 'Gloria', 'Roberts', 'Angry Ants', 76),
#  ('hat', 'Brenda', 'Miller', 'Angry Ants', 73),
#  ('hat', 'Matthew', 'Kelly', 'Angry Ants', 82),
#  ('hat', 'Teresa', 'Perkins', 'Angry Ants', 90),
#  ('hat', 'Nancy', 'Sullivan', 'Angry Ants', 74),
#  ('hat', 'Gloria', 'Reed', 'Angry Ants', 82),
#  ('hat', 'Matthew', 'Chavez', 'Angry Ants', 77),
#  ('hat', 'Lawrence', 'Ryan', 'Angry Ants', 78),
#  ('hat', 'Larry', 'Cole', 'Angry Ants', 74),
#  ('hat', 'Sarah', 'Allen', 'Angry Ants', 76),
#  ('hat', 'Patricia', 'Riley', 'Angry Ants', 76),
#  ('hat', 'Raymond', 'Stephens', 'Angry Ants', 75),
#  ('hat', 'Joyce', 'Perry', 'Angry Ants', 78),
#  ('hat', 'Debra', 'Henry', 'Angry Ants', 82),
#  ('hat', 'Douglas', 'Freeman', 'Angry Ants', 83),
#  ('hat', 'Kevin', 'Fox', 'Angry Ants', 74),
#  ('hat', 'Linda', 'Garrett', 'Angry Ants', 80),
#  ('hat', 'Patrick', 'Gordon', 'Angry Ants', 79),
#  ('hat', 'Katherine', 'Kennedy', 'Angry Ants', 82),
#  ('hat', 'Jeremy', 'Boyd', 'Angry Ants', 90),
#  ('hat', 'Joyce', 'Ward', 'Angry Ants', 69),
#  ('hat', 'John', 'White', 'Angry Ants', 78),
#  ('hat', 'Anna', 'Porter', 'Angry Ants', 82),
#  ('hat', 'Deborah', 'Rivera', 'Angry Ants', 89),
#  ('hat', 'Philip', 'Hudson', 'Angry Ants', 77),
#  ('hat', 'Ronald', 'Gibson', 'Angry Ants', 83),
#  ('hat', 'Joan', 'Barnes', 'Angry Ants', 69),
#  ('hat', 'Kathryn', 'Day', 'Angry Ants', 79),
#  ('hat', 'Mildred', 'Ortiz', 'Angry Ants', 72),
#  ('hat', 'Angela', 'Duncan', 'Angry Ants', 85),
#  ('hat', 'Phyllis', 'George', 'Angry Ants', 81),
#  ('hat', 'Bruce', 'Stone', 'Angry Ants', 82),
#  ('hat', 'Shirley', 'Graham', 'Angry Ants', 83),
#  ('hat', 'Beverly', 'Hudson', 'Angry Ants', 83),
#  ('hat', 'Gloria', 'Reynolds', 'Angry Ants', 85),
#  ('hat', 'Earl', 'Ruiz', 'Angry Ants', 71),
#  ('hat', 'Frank', 'Willis', 'Angry Ants', 83),
#  ('hat', 'Virginia', 'Howell', 'Angry Ants', 81),
#  ('hat', 'Matthew', 'Robinson', 'Angry Ants', 79),
#  ('hat', 'Amy', 'Hart', 'Angry Ants', 88),
#  ('hat', 'Edward', 'Campbell', 'Angry Ants', 79),
#  ('hat', 'Gloria', 'Olson', 'Angry Ants', 71),
#  ('hat', 'Rebecca', 'Hayes', 'Angry Ants', 68),
#  ('hat', 'Rose', 'Jones', 'Angry Ants', 87),
#  ('hat', 'Anthony', 'Palmer', 'Angry Ants', 78),
#  ('hat', 'Bonnie', 'Gibson', 'Angry Ants', 73),
#  ('hat', 'Lori', 'Jones', 'Angry Ants', 75),
#  ('hat', 'Julie', 'Mason', 'Angry Ants', 79),
#  ('hat', 'Ruth', 'Murphy', 'Angry Ants', 76),
#  ('hat', 'Amy', 'Matthews', 'Angry Ants', 75),
#  ('hat', 'Anna', 'Chapman', 'Angry Ants', 82),
#  ('hat', 'Donna', 'Daniels', 'Angry Ants', 78),
#  ('hat', 'Phyllis', 'Hicks', 'Angry Ants', 75),
#  ('hat', 'Michael', 'Hill', 'Angry Ants', 74),
#  ('hat', 'Eugene', 'Welch', 'Angry Ants', 79),
#  ('hat', 'Doris', 'Hunter', 'Angry Ants', 76),
#  ('hat', 'Debra', 'Daniels', 'Angry Ants', 77),
#  ('hat', 'Jack', 'Harvey', 'Angry Ants', 87),
#  ('hat', 'Deborah', 'Johnston', 'Angry Ants', 83),
#  ('hat', 'Michael', 'Kelly', 'Angry Ants', 79),
#  ('hat', 'Edward', 'Hart', 'Angry Ants', 81),
#  ('hat', 'Steven', 'Fox', 'Angry Ants', 79),
#  ('hat', 'Sandra', 'Ferguson', 'Angry Ants', 74),
#  ('hat', 'Lisa', 'Riley', 'Angry Ants', 79),
#  ('hat', 'Carlos', 'Graham', 'Angry Ants', 76),
#  ('hat', 'Heather', 'Foster', 'Angry Ants', 85),
#  ('hat', 'Theresa', 'Fox', 'Angry Ants', 81),
#  ('hat', 'Kathy', 'Ellis', 'Angry Ants', 80),
#  ('hat', 'Diana', 'Torres', 'Angry Ants', 78),
#  ('hat', 'Michelle', 'Marshall', 'Angry Ants', 87),
#  ('hat', 'Katherine', 'Perkins', 'Angry Ants', 73),
#  ('hat', 'Shirley', 'Walker', 'Angry Ants', 89),
#  ('hat', 'Linda', 'Rivera', 'Angry Ants', 80),
#  ('hat', 'Brandon', 'Green', 'Angry Ants', 76),
#  ('hat', 'Douglas', 'Stanley', 'Angry Ants', 79),
#  ('hat', 'Ann', 'Holmes', 'Angry Ants', 76),
#  ('hat', 'Shirley', 'Chavez', 'Angry Ants', 77),
#  ('hat', 'Jane', 'Powell', 'Angry Ants', 73),
#  ('hat', 'Cheryl', 'Burns', 'Angry Ants', 81),
#  ('hat', 'Jose', 'Hunt', 'Angry Ants', 80),
#  ('hat', 'Bobby', 'Stewart', 'Angry Ants', 84),
#  ('hat', 'Emily', 'Carroll', 'Angry Ants', 80),
#  ('hat', 'Norma', 'Willis', 'Angry Ants', 82),
#  ('hat', 'Russell', 'Crawford', 'Angry Ants', 82),
#  ('hat', 'Nicholas', 'Peters', 'Angry Ants', 77),
#  ('hat', 'Justin', 'Dean', 'Angry Ants', 81),
#  ('hat', 'Jennifer', 'Lopez', 'Angry Ants', 81),
#  ('hat', 'Michelle', 'Baker', 'Angry Ants', 85),
#  ('hat', 'Chris', 'Jacobs', 'Angry Ants', 85),
#  ('hat', 'Jose', 'Carroll', 'Angry Ants', 82),
#  ('hat', 'Adam', 'Ford', 'Angry Ants', 77),
#  ('hat', 'Dennis', 'Hicks', 'Angry Ants', 85),
#  ('hat', 'Tina', 'Fox', 'Angry Ants', 77),
#  ('hat', 'Clarence', 'Olson', 'Angry Ants', 80),
#  ('hat', 'Gerald', 'Harrison', 'Angry Ants', 84),
#  ('hat', 'Ashley', 'Rice', 'Angry Ants', 76),
#  ('hat', 'Juan', 'Walker', 'Angry Ants', 81),
#  ('hat', 'Irene', 'Morgan', 'Angry Ants', 67),
#  ('hat', 'Jacqueline', 'Fisher', 'Angry Ants', 76),
#  ('hat', 'George', 'Nguyen', 'Angry Ants', 77),
#  ('hat', 'Randy', 'Day', 'Angry Ants', 84),
#  ('hat', 'Kenneth', 'Gilbert', 'Angry Ants', 72),
#  ('hat', 'Jeremy', 'Tucker', 'Angry Ants', 80),
#  ('hat', 'Russell', 'Green', 'Angry Ants', 81),
#  ('hat', 'Patrick', 'Watkins', 'Angry Ants', 82),
#  ('hat', 'Aaron', 'Davis', 'Angry Ants', 83),
#  ('hat', 'Marie', 'Riley', 'Angry Ants', 72),
#  ('hat', 'Marilyn', 'Williams', 'Angry Ants', 78),
#  ('hat', 'Michael', 'Scott', 'Angry Ants', 74),
#  ('hat', 'Ruth', 'Jackson', 'Angry Ants', 76),
#  ('hat', 'Catherine', 'Garrett', 'Angry Ants', 74),
#  ('hat', 'Carolyn', 'Grant', 'Angry Ants', 87),
#  ('hat', 'Amy', 'Lane', 'Angry Ants', 78),
#  ('hat', 'Russell', 'Dixon', 'Angry Ants', 84),
#  ('hat', 'Ronald', 'Bishop', 'Angry Ants', 77),
#  ('hat', 'Jimmy', 'Gutierrez', 'Angry Ants', 75),
#  ('hat', 'Andrea', 'Butler', 'Angry Ants', 75),
#  ('hat', 'Christopher', 'Walker', 'Angry Ants', 81),
#  ('hat', 'Deborah', 'Snyder', 'Angry Ants', 83),
#  ('hat', 'Adam', 'Gonzales', 'Angry Ants', 76),
#  ('hat', 'Bonnie', 'Olson', 'Angry Ants', 76),
#  ('hat', 'Margaret', 'Myers', 'Angry Ants', 83),
#  ('hat', 'Wayne', 'Stevens', 'Angry Ants', 83),
#  ('hat', 'Lawrence', 'Washington', 'Angry Ants', 85),
#  ('hat', 'Dorothy', 'Cole', 'Angry Ants', 69),
#  ('hat', 'Juan', 'Morgan', 'Angry Ants', 79),
#  ('hat', 'Mark', 'Scott', 'Angry Ants', 83),
#  ('hat', 'Craig', 'Turner', 'Angry Ants', 85),
#  ('hat', 'Brandon', 'Morris', 'Angry Ants', 80),
#  ('hat', 'Lois', 'Cruz', 'Angry Ants', 80),
#  ('hat', 'James', 'Elliott', 'Angry Ants', 74),
#  ('hat', 'Robin', 'Ryan', 'Angry Ants', 75),
#  ('hat', 'Jeffrey', 'Mason', 'Angry Ants', 77),
#  ('hat', 'Brian', 'Bradley', 'Angry Ants', 78),
#  ('hat', 'Anna', 'Jackson', 'Angry Ants', 84),
#  ('hat', 'Richard', 'Russell', 'Angry Ants', 79),
#  ('hat', 'Kenneth', 'Black', 'Angry Ants', 89),
#  ('hat', 'Dorothy', 'Boyd', 'Angry Ants', 73),
#  ('hat', 'Andrea', 'Johnson', 'Angry Ants', 83),
#  ('hat', 'Thomas', 'Jones', 'Angry Ants', 78),
#  ('hat', 'Jimmy', 'Simmons', 'Angry Ants', 88),
#  ('hat', 'Elizabeth', 'Murphy', 'Angry Ants', 74),
#  ('hat', 'Frances', 'Hunter', 'Angry Ants', 84),
#  ('hat', 'John', 'Gray', 'Angry Ants', 90),
#  ('hat', 'Bonnie', 'Brooks', 'Baffled Badgers', 86),
#  ('hat', 'Paul', 'Williamson', 'Baffled Badgers', 77),
#  ('hat', 'Randy', 'Oliver', 'Baffled Badgers', 88),
#  ('hat', 'Nicole', 'Willis', 'Baffled Badgers', 83),
#  ('hat', 'Michelle', 'Nelson', 'Baffled Badgers', 87),
#  ('hat', 'Sharon', 'Brown', 'Baffled Badgers', 84),
#  ('hat', 'Christina', 'Watkins', 'Baffled Badgers', 82),
#  ('hat', 'Sarah', 'Fernandez', 'Baffled Badgers', 86),
#  ('hat', 'Teresa', 'Martinez', 'Baffled Badgers', 83),
#  ('hat', 'Rose', 'Kelley', 'Baffled Badgers', 84),
#  ('hat', 'Sharon', 'Foster', 'Baffled Badgers', 85),
#  ('hat', 'Jennifer', 'Lawson', 'Baffled Badgers', 91),
#  ('hat', 'Kimberly', 'Fernandez', 'Baffled Badgers', 80),
#  ('hat', 'Howard', 'Gilbert', 'Baffled Badgers', 82),
#  ('hat', 'Sarah', 'Payne', 'Baffled Badgers', 87),
#  ('hat', 'Joyce', 'Marshall', 'Baffled Badgers', 80),
#  ('hat', 'Kelly', 'Perkins', 'Baffled Badgers', 82),
#  ('hat', 'Darren', 'Greene', 'Baffled Badgers', 85),
#  ('hat', 'Nicole', 'Powell', 'Baffled Badgers', 85),
#  ('hat', 'Nicole', 'Carter', 'Baffled Badgers', 89),
#  ('hat', 'Nicholas', 'Cruz', 'Baffled Badgers', 87),
#  ('hat', 'Lori', 'Watson', 'Baffled Badgers', 80),
#  ('hat', 'Johnny', 'Lopez', 'Baffled Badgers', 87),
#  ('hat', 'Billy', 'Gray', 'Baffled Badgers', 85),
#  ('hat', 'Lillian', 'Rodriguez', 'Baffled Badgers', 77),
#  ('hat', 'Rachel', 'Robinson', 'Baffled Badgers', 85),
#  ('hat', 'Joan', 'Watkins', 'Baffled Badgers', 85),
#  ('hat', 'Andrew', 'Peterson', 'Baffled Badgers', 84),
#  ('hat', 'Ronald', 'Hughes', 'Baffled Badgers', 92),
#  ('hat', 'Larry', 'Gomez', 'Baffled Badgers', 87),
#  ('hat', 'Walter', 'Hughes', 'Baffled Badgers', 71),
#  ('hat', 'Deborah', 'Lee', 'Baffled Badgers', 84),
#  ('hat', 'William', 'Howard', 'Baffled Badgers', 84),
#  ('hat', 'Martha', 'Cruz', 'Baffled Badgers', 84),
#  ('hat', 'Arthur', 'Bishop', 'Baffled Badgers', 91),
#  ('hat', 'Debra', 'Frazier', 'Baffled Badgers', 80),
#  ('hat', 'Alice', 'Miller', 'Baffled Badgers', 91),
#  ('hat', 'Linda', 'Matthews', 'Baffled Badgers', 92),
#  ('hat', 'Todd', 'Ross', 'Baffled Badgers', 81),
#  ('hat', 'Doris', 'Washington', 'Baffled Badgers', 85),
#  ('hat', 'Randy', 'Wells', 'Baffled Badgers', 94),
#  ('hat', 'Thomas', 'Oliver', 'Baffled Badgers', 85),
#  ('hat', 'Dennis', 'Bishop', 'Baffled Badgers', 91),
#  ('hat', 'Gary', 'Greene', 'Baffled Badgers', 79),
#  ('hat', 'Keith', 'Scott', 'Baffled Badgers', 73),
#  ('hat', 'Terry', 'Bradley', 'Baffled Badgers', 94),
#  ('hat', 'David', 'Hunter', 'Baffled Badgers', 78),
#  ('hat', 'Ronald', 'Thomas', 'Baffled Badgers', 79),
#  ('hat', 'Adam', 'West', 'Baffled Badgers', 81),
#  ('hat', 'Christina', 'Graham', 'Baffled Badgers', 90),
#  ('hat', 'Stephanie', 'Ryan', 'Baffled Badgers', 88),
#  ('hat', 'Robin', 'Gardner', 'Baffled Badgers', 85),
#  ('hat', 'Rebecca', 'Henderson', 'Baffled Badgers', 88),
#  ('hat', 'Ruth', 'Peterson', 'Baffled Badgers', 77),
#  ('hat', 'Roy', 'Stanley', 'Baffled Badgers', 89),
#  ('hat', 'Jimmy', 'Wagner', 'Baffled Badgers', 83),
#  ('hat', 'George', 'White', 'Baffled Badgers', 85),
#  ('hat', 'Mark', 'Williams', 'Baffled Badgers', 80),
#  ('hat', 'Robin', 'Wheeler', 'Baffled Badgers', 89),
#  ('hat', 'William', 'Mason', 'Baffled Badgers', 86),
#  ('hat', 'Gerald', 'Ortiz', 'Baffled Badgers', 85),
#  ('hat', 'Cheryl', 'Elliott', 'Baffled Badgers', 79),
#  ('hat', 'Andrew', 'Moreno', 'Baffled Badgers', 90),
#  ('hat', 'Ryan', 'Webb', 'Baffled Badgers', 82),
#  ('hat', 'Carlos', 'Howell', 'Baffled Badgers', 75),
#  ('hat', 'Sean', 'Lane', 'Baffled Badgers', 89),
#  ('hat', 'Carolyn', 'Carter', 'Baffled Badgers', 94),
#  ('hat', 'Kimberly', 'Chavez', 'Baffled Badgers', 80),
#  ('hat', 'Kathy', 'Collins', 'Baffled Badgers', 90),
#  ('hat', 'Philip', 'Arnold', 'Baffled Badgers', 86),
#  ('hat', 'Julie', 'Grant', 'Baffled Badgers', 83),
#  ('hat', 'Eric', 'Turner', 'Baffled Badgers', 87),
#  ('hat', 'Stephanie', 'Ruiz', 'Baffled Badgers', 81),
#  ('hat', 'Christopher', 'Hunter', 'Baffled Badgers', 82),
#  ('hat', 'Joyce', 'Henry', 'Baffled Badgers', 77),
#  ('hat', 'Irene', 'Bowman', 'Baffled Badgers', 80),
#  ('hat', 'Clarence', 'Williamson', 'Baffled Badgers', 80),
#  ('hat', 'Thomas', 'Rivera', 'Baffled Badgers', 83),
#  ('hat', 'Catherine', 'King', 'Baffled Badgers', 83),
#  ('hat', 'Lois', 'Gordon', 'Baffled Badgers', 86),
#  ('hat', 'Cynthia', 'Alexander', 'Baffled Badgers', 92),
#  ('hat', 'Martha', 'Bell', 'Baffled Badgers', 77),
#  ('hat', 'Gloria', 'Wells', 'Baffled Badgers', 79),
#  ('hat', 'Keith', 'Butler', 'Baffled Badgers', 82),
#  ('hat', 'Kelly', 'Burns', 'Baffled Badgers', 79),
#  ('hat', 'Samuel', 'Berry', 'Baffled Badgers', 82),
#  ('hat', 'Johnny', 'Jacobs', 'Baffled Badgers', 80),
#  ('hat', 'Kathy', 'Gilbert', 'Baffled Badgers', 84),
#  ('hat', 'Emily', 'Johnson', 'Baffled Badgers', 85),
#  ('hat', 'Evelyn', 'Austin', 'Baffled Badgers', 87),
#  ('hat', 'Catherine', 'Peters', 'Baffled Badgers', 85),
#  ('hat', 'Charles', 'Grant', 'Baffled Badgers', 85),
#  ('hat', 'Philip', 'Brown', 'Baffled Badgers', 94),
#  ('hat', 'Donna', 'Flores', 'Baffled Badgers', 89),
#  ('hat', 'Patricia', 'Ryan', 'Baffled Badgers', 83),
#  ('hat', 'Stephen', 'Wallace', 'Baffled Badgers', 94),
#  ('hat', 'William', 'Martinez', 'Baffled Badgers', 89),
#  ('hat', 'Linda', 'Bowman', 'Baffled Badgers', 85),
#  ('hat', 'Justin', 'Olson', 'Baffled Badgers', 87),
#  ('hat', 'Alice', 'Bennett', 'Baffled Badgers', 81),
#  ('hat', 'Brian', 'Matthews', 'Baffled Badgers', 90),
#  ('hat', 'Phillip', 'Crawford', 'Baffled Badgers', 83),
#  ('hat', 'Mary', 'Gray', 'Baffled Badgers', 74),
#  ('hat', 'Brandon', 'Hicks', 'Baffled Badgers', 78),
#  ('hat', 'Harry', 'Welch', 'Baffled Badgers', 92),
#  ('hat', 'Charles', 'Torres', 'Baffled Badgers', 79),
#  ('hat', 'Joe', 'Ellis', 'Baffled Badgers', 93),
#  ('hat', 'Charles', 'Hansen', 'Baffled Badgers', 80),
#  ('hat', 'Susan', 'Pierce', 'Baffled Badgers', 89),
#  ('hat', 'Stephanie', 'Flores', 'Baffled Badgers', 86),
#  ('hat', 'Arthur', 'Carroll', 'Baffled Badgers', 85),
#  ('hat', 'Martin', 'Richardson', 'Baffled Badgers', 87),
#  ('hat', 'Keith', 'Perez', 'Baffled Badgers', 92),
#  ('hat', 'Cynthia', 'Carroll', 'Baffled Badgers', 82),
#  ('hat', 'Craig', 'Payne', 'Baffled Badgers', 83),
#  ('hat', 'Charles', 'Green', 'Baffled Badgers', 84),
#  ('hat', 'Wayne', 'McDarren', 'Baffled Badgers', 79),
#  ('hat', 'Joyce', 'Morgan', 'Baffled Badgers', 81),
#  ('hat', 'Benjamin', 'Hernandez', 'Baffled Badgers', 89),
#  ('hat', 'Andrew', 'Lane', 'Baffled Badgers', 81),
#  ('hat', 'Michelle', 'Roberts', 'Baffled Badgers', 84),
#  ('hat', 'Kathy', 'West', 'Baffled Badgers', 82),
#  ('hat', 'Alice', 'Brown', 'Baffled Badgers', 84),
#  ('hat', 'Sara', 'Wallace', 'Baffled Badgers', 81),
#  ('hat', 'Ruth', 'Taylor', 'Baffled Badgers', 81),
#  ('hat', 'Keith', 'Knight', 'Baffled Badgers', 85),
#  ('hat', 'Carolyn', 'Ruiz', 'Baffled Badgers', 81),
#  ('hat', 'Ashley', 'Ramirez', 'Baffled Badgers', 86),
#  ('hat', 'Susan', 'Greene', 'Baffled Badgers', 90),
#  ('hat', 'Lillian', 'Cunningham', 'Baffled Badgers', 85),
#  ('hat', 'Matthew', 'Franklin', 'Baffled Badgers', 87),
#  ('hat', 'Keith', 'Peters', 'Baffled Badgers', 88),
#  ('hat', 'Eugene', 'Perry', 'Baffled Badgers', 89),
#  ('hat', 'Thomas', 'Williamson', 'Baffled Badgers', 83),
#  ('hat', 'Daniel', 'Hunt', 'Baffled Badgers', 84),
#  ('hat', 'Nancy', 'Henderson', 'Baffled Badgers', 77),
#  ('hat', 'Annie', 'Collins', 'Baffled Badgers', 81),
#  ('hat', 'Kimberly', 'Payne', 'Baffled Badgers', 79),
#  ('hat', 'Jennifer', 'Warren', 'Baffled Badgers', 92),
#  ('hat', 'Ernest', 'Woods', 'Baffled Badgers', 85),
#  ('hat', 'Adam', 'Knight', 'Baffled Badgers', 90),
#  ('hat', 'Thomas', 'Hanson', 'Baffled Badgers', 84),
#  ('hat', 'David', 'Wheeler', 'Baffled Badgers', 81),
#  ('hat', 'Ruby', 'Richards', 'Baffled Badgers', 85),
#  ('hat', 'Tammy', 'Wagner', 'Baffled Badgers', 88),
#  ('hat', 'Ruth', 'Jones', 'Baffled Badgers', 91),
#  ('hat', 'Michelle', 'Carr', 'Baffled Badgers', 86),
#  ('hat', 'Christine', 'Marshall', 'Baffled Badgers', 82),
#  ('hat', 'Wanda', 'Alexander', 'Baffled Badgers', 80),
#  ('hat', 'Eugene', 'Flores', 'Baffled Badgers', 87),
#  ('hat', 'Judith', 'Barnes', 'Baffled Badgers', 87),
#  ('hat', 'Earl', 'Evans', 'Baffled Badgers', 94),
#  ('hat', 'Keith', 'Pierce', 'Baffled Badgers', 87),
#  ('hat', 'Shirley', 'Ramirez', 'Baffled Badgers', 88),
#  ('hat', 'Richard', 'Patterson', 'Baffled Badgers', 91),
#  ('hat', 'Anne', 'Romero', 'Baffled Badgers', 86),
#  ('hat', 'Louise', 'Garcia', 'Baffled Badgers', 90),
#  ('hat', 'Gary', 'Parker', 'Baffled Badgers', 83),
#  ('hat', 'Nancy', 'Shaw', 'Baffled Badgers', 90),
#  ('hat', 'Eric', 'Gardner', 'Baffled Badgers', 93),
#  ('hat', 'William', 'Carroll', 'Baffled Badgers', 89),
#  ('hat', 'Brandon', 'Greene', 'Baffled Badgers', 77),
#  ('hat', 'Howard', 'Morris', 'Baffled Badgers', 85),
#  ('hat', 'Stephen', 'Grant', 'Baffled Badgers', 89),
#  ('hat', 'Rebecca', 'Jones', 'Baffled Badgers', 79),
#  ('hat', 'Jessica', 'Price', 'Baffled Badgers', 90),
#  ('hat', 'Paul', 'Walker', 'Baffled Badgers', 77),
#  ('hat', 'Mildred', 'Crawford', 'Baffled Badgers', 88),
#  ('hat', 'Douglas', 'Boyd', 'Baffled Badgers', 98),
#  ('hat', 'Ernest', 'Reed', 'Baffled Badgers', 86),
#  ('hat', 'Norma', 'Morales', 'Baffled Badgers', 82),
#  ('hat', 'Roy', 'Black', 'Baffled Badgers', 87),
#  ('hat', 'Mary', 'Richards', 'Baffled Badgers', 81),
#  ('hat', 'John', 'Myers', 'Baffled Badgers', 93),
#  ('hat', 'Annie', 'Turner', 'Baffled Badgers', 76),
#  ('hat', 'Phillip', 'Stone', 'Baffled Badgers', 81),
#  ('hat', 'Irene', 'Watkins', 'Baffled Badgers', 85),
#  ('hat', 'Brian', 'Bowman', 'Baffled Badgers', 87),
#  ('hat', 'Jacqueline', 'Dixon', 'Baffled Badgers', 86),
#  ('hat', 'Denise', 'White', 'Baffled Badgers', 86),
#  ('hat', 'Ashley', 'Washington', 'Baffled Badgers', 94),
#  ('hat', 'Brenda', 'Owens', 'Baffled Badgers', 78),
#  ('hat', 'Roger', 'Harrison', 'Baffled Badgers', 87),
#  ('hat', 'Andrew', 'Taylor', 'Baffled Badgers', 86),
#  ('hat', 'Wayne', 'Williams', 'Baffled Badgers', 84),
#  ('hat', 'Stephanie', 'Gomez', 'Baffled Badgers', 80),
#  ('hat', 'Theresa', 'Torres', 'Baffled Badgers', 85),
#  ('hat', 'Douglas', 'Peterson', 'Baffled Badgers', 84),
#  ('hat', 'Melissa', 'Richardson', 'Baffled Badgers', 79),
#  ('hat', 'Brenda', 'Brooks', 'Baffled Badgers', 88),
#  ('hat', 'Judith', 'Cole', 'Baffled Badgers', 89),
#  ('hat', 'Darren', 'Woods', 'Baffled Badgers', 87),
#  ('hat', 'Marilyn', 'Payne', 'Baffled Badgers', 92),
#  ('hat', 'Willie', 'Olson', 'Baffled Badgers', 78),
#  ('hat', 'Janice', 'Howell', 'Cosmic Cobras', 92),
#  ('hat', 'Dennis', 'Banks', 'Cosmic Cobras', 85),
#  ('hat', 'Brian', 'George', 'Cosmic Cobras', 82),
#  ('hat', 'Earl', 'Snyder', 'Cosmic Cobras', 85),
#  ('hat', 'Scott', 'Thompson', 'Cosmic Cobras', 100),
#  ('hat', 'John', 'Howard', 'Cosmic Cobras', 85),
#  ('hat', 'Margaret', 'Hamilton', 'Cosmic Cobras', 96),
#  ('hat', 'Janet', 'Rodriguez', 'Cosmic Cobras', 92),
#  ('hat', 'Tina', 'Greene', 'Cosmic Cobras', 90),
#  ('hat', 'Robert', 'Bradley', 'Cosmic Cobras', 87),
#  ('hat', 'Carlos', 'Gray', 'Cosmic Cobras', 89),
#  ('hat', 'Catherine', 'Rodriguez', 'Cosmic Cobras', 100),
#  ('hat', 'Victor', 'Shaw', 'Cosmic Cobras', 91),
#  ('hat', 'Philip', 'Ray', 'Cosmic Cobras', 85),
#  ('hat', 'Willie', 'Thomas', 'Cosmic Cobras', 91),
#  ('hat', 'Keith', 'Ferguson', 'Cosmic Cobras', 86),
#  ('hat', 'Kevin', 'Martinez', 'Cosmic Cobras', 86),
#  ('hat', 'Matthew', 'Bowman', 'Cosmic Cobras', 89),
#  ('hat', 'Angela', 'Martinez', 'Cosmic Cobras', 90),
#  ('hat', 'Tina', 'Alexander', 'Cosmic Cobras', 91),
#  ('hat', 'Kimberly', 'Black', 'Cosmic Cobras', 94),
#  ('hat', 'Jason', 'Cole', 'Cosmic Cobras', 89),
#  ('hat', 'David', 'Davis', 'Cosmic Cobras', 89),
#  ('hat', 'Ruth', 'Scott', 'Cosmic Cobras', 87),
#  ('hat', 'Diana', 'Gonzales', 'Cosmic Cobras', 87),
#  ('hat', 'Jennifer', 'Morgan', 'Cosmic Cobras', 95),
#  ('hat', 'Karen', 'Kelley', 'Cosmic Cobras', 89),
#  ('hat', 'Kathryn', 'Welch', 'Cosmic Cobras', 100),
#  ('hat', 'Carlos', 'Morrrison', 'Cosmic Cobras', 87),
#  ('hat', 'Lois', 'Coleman', 'Cosmic Cobras', 92),
#  ('hat', 'Denise', 'Gutierrez', 'Cosmic Cobras', 93),
#  ('hat', 'Jerry', 'Watkins', 'Cosmic Cobras', 98),
#  ('hat', 'Bruce', 'Phillips', 'Cosmic Cobras', 90),
#  ('hat', 'Jose', 'Cooper', 'Cosmic Cobras', 89),
#  ('hat', 'Gerald', 'Price', 'Cosmic Cobras', 89),
#  ('hat', 'Judy', 'Ramirez', 'Cosmic Cobras', 90),
#  ('hat', 'Joan', 'Perkins', 'Cosmic Cobras', 95),
#  ('hat', 'Carl', 'Mendoza', 'Cosmic Cobras', 90),
#  ('hat', 'Terry', 'Fernandez', 'Cosmic Cobras', 100),
#  ('hat', 'Chris', 'Wilson', 'Cosmic Cobras', 87),
#  ('hat', 'Andrea', 'Hart', 'Cosmic Cobras', 91),
#  ('hat', 'Wayne', 'Young', 'Cosmic Cobras', 89),
#  ('hat', 'Susan', 'Dixon', 'Cosmic Cobras', 89),
#  ('hat', 'Harry', 'Freeman', 'Cosmic Cobras', 87),
#  ('hat', 'David', 'Roberts', 'Cosmic Cobras', 89),
#  ('hat', 'Joan', 'Elliott', 'Cosmic Cobras', 90),
#  ('hat', 'Christopher', 'Kim', 'Cosmic Cobras', 90),
#  ('hat', 'Peter', 'Murray', 'Cosmic Cobras', 93),
#  ('hat', 'Darren', 'Phillips', 'Cosmic Cobras', 85),
#  ('hat', 'Roy', 'Clark', 'Cosmic Cobras', 83),
#  ('hat', 'Janice', 'Peterson', 'Cosmic Cobras', 89),
#  ('hat', 'Emily', 'Richards', 'Cosmic Cobras', 84),
#  ('hat', 'Norma', 'Simpson', 'Cosmic Cobras', 95),
#  ('hat', 'Lisa', 'Wallace', 'Cosmic Cobras', 89),
#  ('hat', 'Christine', 'Jacobs', 'Cosmic Cobras', 88),
#  ('hat', 'Todd', 'Mason', 'Cosmic Cobras', 88),
#  ('hat', 'Amy', 'Warren', 'Cosmic Cobras', 92),
#  ('hat', 'Angela', 'Russell', 'Cosmic Cobras', 93),
#  ('hat', 'Stephen', 'Fernandez', 'Cosmic Cobras', 97),
#  ('hat', 'Kathy', 'Riley', 'Cosmic Cobras', 97),
#  ('hat', 'Annie', 'Kennedy', 'Cosmic Cobras', 94),
#  ('hat', 'Sandra', 'Bryant', 'Cosmic Cobras', 87),
#  ('hat', 'Ashley', 'Burton', 'Cosmic Cobras', 88),
#  ('hat', 'Lillian', 'Kim', 'Cosmic Cobras', 90),
#  ('hat', 'Helen', 'Thompson', 'Cosmic Cobras', 92),
#  ('hat', 'Bobby', 'Garrett', 'Cosmic Cobras', 92),
#  ('hat', 'Judy', 'Johnson', 'Cosmic Cobras', 89),
#  ('hat', 'Harold', 'Richards', 'Cosmic Cobras', 91),
#  ('hat', 'Jason', 'West', 'Cosmic Cobras', 80),
#  ('hat', 'Christina', 'Richardson', 'Cosmic Cobras', 91),
#  ('hat', 'Justin', 'Stanley', 'Cosmic Cobras', 90),
#  ('hat', 'Walter', 'Hamilton', 'Cosmic Cobras', 86),
#  ('hat', 'Todd', 'Richards', 'Cosmic Cobras', 83),
#  ('hat', 'Christine', 'Rivera', 'Cosmic Cobras', 89),
#  ('hat', 'Raymond', 'Butler', 'Cosmic Cobras', 93),
#  ('hat', 'Joshua', 'Perkins', 'Cosmic Cobras', 79),
#  ('hat', 'Angela', 'Cunningham', 'Cosmic Cobras', 94),
#  ('hat', 'Ryan', 'Hayes', 'Cosmic Cobras', 84),
#  ('hat', 'Howard', 'Ramirez', 'Cosmic Cobras', 80),
#  ('hat', 'Louis', 'Cox', 'Cosmic Cobras', 90),
#  ('hat', 'Louise', 'Fisher', 'Cosmic Cobras', 82),
#  ('hat', 'Terry', 'Grant', 'Cosmic Cobras', 92),
#  ('hat', 'Juan', 'Murphy', 'Cosmic Cobras', 90),
#  ('hat', 'Walter', 'Medina', 'Cosmic Cobras', 88),
#  ('hat', 'Charles', 'Diaz', 'Cosmic Cobras', 90),
#  ('hat', 'Raymond', 'Bailey', 'Cosmic Cobras', 97),
#  ('hat', 'Frank', 'Perkins', 'Cosmic Cobras', 94),
#  ('hat', 'Raymond', 'Moore', 'Cosmic Cobras', 88),
#  ('hat', 'Philip', 'Foster', 'Cosmic Cobras', 92),
#  ('hat', 'Michelle', 'Mason', 'Cosmic Cobras', 77),
#  ('hat', 'Ryan', 'Holmes', 'Cosmic Cobras', 87),
#  ('hat', 'Irene', 'Crawford', 'Cosmic Cobras', 93),
#  ('hat', 'Carl', 'Olson', 'Cosmic Cobras', 86),
#  ('hat', 'Ernest', 'Fowler', 'Cosmic Cobras', 96),
#  ('hat', 'Jose', 'Butler', 'Cosmic Cobras', 88),
#  ('hat', 'Annie', 'Jackson', 'Cosmic Cobras', 93),
#  ('hat', 'William', 'Black', 'Cosmic Cobras', 94),
#  ('hat', 'Andrew', 'Mason', 'Cosmic Cobras', 90),
#  ('hat', 'Walter', 'Kelly', 'Cosmic Cobras', 87),
#  ('hat', 'Jack', 'Martinez', 'Cosmic Cobras', 87),
#  ('hat', 'Judy', 'Black', 'Cosmic Cobras', 87),
#  ('hat', 'Virginia', 'Harvey', 'Cosmic Cobras', 93),
#  ('hat', 'Jeremy', 'Martin', 'Cosmic Cobras', 88),
#  ('hat', 'Steven', 'Foster', 'Cosmic Cobras', 95),
#  ('hat', 'Fred', 'Williamson', 'Cosmic Cobras', 93),
#  ('hat', 'Steve', 'Cook', 'Cosmic Cobras', 86),
#  ('hat', 'Bruce', 'Ross', 'Cosmic Cobras', 86),
#  ('hat', 'Bruce', 'Wallace', 'Cosmic Cobras', 84),
#  ('hat', 'Melissa', 'Olson', 'Cosmic Cobras', 98),
#  ('hat', 'Shawn', 'Ryan', 'Cosmic Cobras', 88),
#  ('hat', 'Jack', 'Butler', 'Cosmic Cobras', 82),
#  ('hat', 'Ernest', 'Peters', 'Cosmic Cobras', 90),
#  ('hat', 'Earl', 'Russell', 'Cosmic Cobras', 94),
#  ('hat', 'Ruby', 'Mendoza', 'Cosmic Cobras', 85),
#  ('hat', 'Anthony', 'Morris', 'Cosmic Cobras', 91),
#  ('hat', 'Kelly', 'Lewis', 'Cosmic Cobras', 95),
#  ('hat', 'Eric', 'Morgan', 'Cosmic Cobras', 77),
#  ('hat', 'Anna', 'Foster', 'Cosmic Cobras', 83),
#  ('hat', 'Jennifer', 'Reynolds', 'Cosmic Cobras', 88),
#  ('hat', 'Helen', 'Reyes', 'Cosmic Cobras', 88),
#  ('hat', 'Kenneth', 'Fisher', 'Cosmic Cobras', 92),
#  ('hat', 'Ruby', 'Kelley', 'Cosmic Cobras', 96),
#  ('hat', 'Benjamin', 'Duncan', 'Cosmic Cobras', 84),
#  ('hat', 'Arthur', 'Dunn', 'Cosmic Cobras', 91),
#  ('hat', 'Sean', 'Webb', 'Cosmic Cobras', 87),
#  ('hat', 'Brian', 'Frazier', 'Cosmic Cobras', 94),
#  ('hat', 'Sarah', 'Johnston', 'Cosmic Cobras', 87),
#  ('hat', 'Julia', 'Williams', 'Cosmic Cobras', 84),
#  ('hat', 'Adam', 'Richardson', 'Cosmic Cobras', 89),
#  ('hat', 'Stephanie', 'Carpenter', 'Cosmic Cobras', 89),
#  ('hat', 'Edward', 'Hicks', 'Cosmic Cobras', 98),
#  ('hat', 'Steve', 'Jenkins', 'Cosmic Cobras', 85),
#  ('hat', 'Rebecca', 'Cunningham', 'Cosmic Cobras', 87),
#  ('hat', 'Harold', 'Collins', 'Cosmic Cobras', 86),
#  ('hat', 'Carl', 'Pierce', 'Cosmic Cobras', 93),
#  ('hat', 'Edward', 'Sanchez', 'Cosmic Cobras', 90),
#  ('hat', 'Barbara', 'Bryant', 'Cosmic Cobras', 80),
#  ('hat', 'Julia', 'Carroll', 'Cosmic Cobras', 92),
#  ('hat', 'Earl', 'Simmons', 'Cosmic Cobras', 97),
#  ('hat', 'Mary', 'Myers', 'Cosmic Cobras', 88),
#  ('hat', 'Carolyn', 'Griffin', 'Cosmic Cobras', 89),
#  ('hat', 'Ruby', 'Burton', 'Cosmic Cobras', 93),
#  ('hat', 'Donna', 'Armstrong', 'Cosmic Cobras', 84),
#  ('hat', 'Sharon', 'Roberts', 'Cosmic Cobras', 91),
#  ('hat', 'Michelle', 'Hawkins', 'Cosmic Cobras', 90),
#  ('hat', 'Nicole', 'Moreno', 'Cosmic Cobras', 91),
#  ('hat', 'Roger', 'Tucker', 'Cosmic Cobras', 93),
#  ('hat', 'Janet', 'Reynolds', 'Cosmic Cobras', 91),
#  ('hat', 'Julia', 'Lee', 'Cosmic Cobras', 100),
#  ('hat', 'Eugene', 'Martinez', 'Cosmic Cobras', 79),
#  ('hat', 'Pamela', 'Payne', 'Cosmic Cobras', 97),
#  ('hat', 'Brandon', 'Lopez', 'Cosmic Cobras', 87),
#  ('hat', 'Daniel', 'George', 'Cosmic Cobras', 93),
#  ('hat', 'Emily', 'Berry', 'Cosmic Cobras', 95),
#  ('hat', 'Jesse', 'Garcia', 'Cosmic Cobras', 87),
#  ('hat', 'Margaret', 'Weaver', 'Cosmic Cobras', 89),
#  ('hat', 'Justin', 'Washington', 'Cosmic Cobras', 92),
#  ('hat', 'Deborah', 'Meyer', 'Cosmic Cobras', 91),
#  ('hat', 'Bruce', 'King', 'Cosmic Cobras', 81),
#  ('hat', 'Jane', 'Lopez', 'Cosmic Cobras', 88),
#  ('hat', 'Paul', 'Williams', 'Cosmic Cobras', 88),
#  ('hat', 'Katherine', 'Holmes', 'Cosmic Cobras', 91),
#  ('hat', 'Steve', 'Cooper', 'Cosmic Cobras', 81),
#  ('hat', 'Nicholas', 'Barnes', 'Cosmic Cobras', 88),
#  ('hat', 'Melissa', 'Franklin', 'Cosmic Cobras', 86),
#  ('hat', 'Christina', 'Burns', 'Cosmic Cobras', 96),
#  ('hat', 'Peter', 'Hawkins', 'Cosmic Cobras', 82),
#  ('hat', 'David', 'Thomas', 'Cosmic Cobras', 91),
#  ('hat', 'Adam', 'Garcia', 'Cosmic Cobras', 91),
#  ('hat', 'Anthony', 'Warren', 'Cosmic Cobras', 93),
#  ('hat', 'Melissa', 'Hughes', 'Cosmic Cobras', 85),
#  ('hat', 'Donna', 'Johnston', 'Cosmic Cobras', 90),
#  ('hat', 'Cheryl', 'Wallace', 'Cosmic Cobras', 88),
#  ('hat', 'Edward', 'McDarren', 'Cosmic Cobras', 93),
#  ('hat', 'Victor', 'Hunt', 'Cosmic Cobras', 89),
#  ('hat', 'Alice', 'Shaw', 'Cosmic Cobras', 94),
#  ('hat', 'Roy', 'Arnold', 'Cosmic Cobras', 81),
#  ('hat', 'Jennifer', 'Burke', 'Cosmic Cobras', 83),
#  ('hat', 'Christine', 'Reyes', 'Cosmic Cobras', 91),
#  ('hat', 'Juan', 'Bradley', 'Cosmic Cobras', 93),
#  ('hat', 'Carlos', 'Chapman', 'Cosmic Cobras', 84),
#  ('hat', 'Maria', 'Palmer', 'Cosmic Cobras', 90),
#  ('hat', 'Carol', 'Campbell', 'Cosmic Cobras', 87),
#  ('hat', 'Marilyn', 'Hall', 'Cosmic Cobras', 90),
#  ('hat', 'Kevin', 'Garcia', 'Cosmic Cobras', 81),
#  ('hat', 'Randy', 'Larson', 'Cosmic Cobras', 91),
#  ('hat', 'Jesse', 'Gardner', 'Cosmic Cobras', 96),
#  ('hat', 'James', 'Payne', 'Cosmic Cobras', 94),
#  ('shirt', 'Wanda', 'Alvarez', 'Angry Ants', 80),
#  ('shirt', 'Ryan', 'Rice', 'Angry Ants', 84),
#  ('shirt', 'Paula', 'Montgomery', 'Angry Ants', 87),
#  ('shirt', 'Gerald', 'Johnston', 'Angry Ants', 78),
#  ('shirt', 'James', 'Graham', 'Angry Ants', 82),
#  ('shirt', 'Helen', 'Berry', 'Angry Ants', 78),
#  ('shirt', 'Gerald', 'Montgomery', 'Angry Ants', 85),
#  ('shirt', 'Jacqueline', 'Morales', 'Angry Ants', 88),
#  ('shirt', 'Paul', 'Schmidt', 'Angry Ants', 76),
#  ('shirt', 'Lawrence', 'Hill', 'Angry Ants', 81),
#  ('shirt', 'Dennis', 'Harper', 'Angry Ants', 83),
#  ('shirt', 'Robert', 'Hart', 'Angry Ants', 80),
#  ('shirt', 'Judith', 'Mason', 'Angry Ants', 79),
#  ('shirt', 'Matthew', 'Woods', 'Angry Ants', 82),
#  ('shirt', 'Ralph', 'Burke', 'Angry Ants', 73),
#  ('shirt', 'Maria', 'Simmons', 'Angry Ants', 73),
#  ('shirt', 'Lawrence', 'Torres', 'Angry Ants', 75),
#  ('shirt', 'Andrew', 'Parker', 'Angry Ants', 76),
#  ('shirt', 'Jerry', 'Fisher', 'Angry Ants', 79),
#  ('shirt', 'Jacqueline', 'Stanley', 'Angry Ants', 85),
#  ('shirt', 'Phyllis', 'Webb', 'Angry Ants', 72),
#  ('shirt', 'Jeffrey', 'Dunn', 'Angry Ants', 74),
#  ('shirt', 'Keith', 'Gordon', 'Angry Ants', 83),
#  ('shirt', 'Carolyn', 'Mills', 'Angry Ants', 80),
#  ('shirt', 'Ryan', 'Ramos', 'Angry Ants', 84),
#  ('shirt', 'Kevin', 'Russell', 'Angry Ants', 81),
#  ('shirt', 'Joan', 'Vasquez', 'Angry Ants', 85),
#  ('shirt', 'Emily', 'Elliott', 'Angry Ants', 76),
#  ('shirt', 'Kevin', 'Clark', 'Angry Ants', 67),
#  ('shirt', 'Cheryl', 'Sims', 'Angry Ants', 82),
#  ('shirt', 'Lori', 'Johnson', 'Angry Ants', 84),
#  ('shirt', 'Nicole', 'Wallace', 'Angry Ants', 73),
#  ('shirt', 'Ashley', 'Harper', 'Angry Ants', 85),
#  ('shirt', 'Katherine', 'Warren', 'Angry Ants', 72),
#  ('shirt', 'Melissa', 'Palmer', 'Angry Ants', 81),
#  ('shirt', 'Bonnie', 'Sanchez', 'Angry Ants', 78),
#  ('shirt', 'Thomas', 'Martin', 'Angry Ants', 76),
#  ('shirt', 'Rose', 'Burton', 'Angry Ants', 80),
#  ('shirt', 'Carolyn', 'Henry', 'Angry Ants', 74),
#  ('shirt', 'Janet', 'Ferguson', 'Angry Ants', 79),
#  ('shirt', 'Steven', 'Green', 'Angry Ants', 73),
#  ('shirt', 'Wayne', 'Gutierrez', 'Angry Ants', 88),
#  ('shirt', 'Martha', 'Gardner', 'Angry Ants', 72),
#  ('shirt', 'Andrew', 'Cox', 'Angry Ants', 81),
#  ('shirt', 'Henry', 'Kim', 'Angry Ants', 80),
#  ('shirt', 'Betty', 'Hall', 'Angry Ants', 70),
#  ('shirt', 'Shirley', 'Montgomery', 'Angry Ants', 77),
#  ('shirt', 'Walter', 'Clark', 'Angry Ants', 79),
#  ('shirt', 'Jennifer', 'Garrett', 'Angry Ants', 90),
#  ('shirt', 'Phyllis', 'Clark', 'Angry Ants', 81),
#  ('shirt', 'Jason', 'Daniels', 'Angry Ants', 71),
#  ('shirt', 'Beverly', 'Garza', 'Angry Ants', 77),
#  ('shirt', 'Carl', 'Greene', 'Angry Ants', 79),
#  ('shirt', 'Kathryn', 'Banks', 'Angry Ants', 79),
#  ('shirt', 'Patrick', 'Hunt', 'Angry Ants', 75),
#  ('shirt', 'Gerald', 'Freeman', 'Angry Ants', 83),
#  ('shirt', 'Cheryl', 'Phillips', 'Angry Ants', 72),
#  ('shirt', 'Cynthia', 'Powell', 'Angry Ants', 86),
#  ('shirt', 'George', 'Gonzalez', 'Angry Ants', 81),
#  ('shirt', 'John', 'Sanders', 'Angry Ants', 72),
#  ('shirt', 'Willie', 'Elliott', 'Angry Ants', 86),
#  ('shirt', 'Marie', 'Reynolds', 'Angry Ants', 81),
#  ('shirt', 'Chris', 'Castillo', 'Angry Ants', 76),
#  ('shirt', 'Marie', 'Hawkins', 'Angry Ants', 76),
#  ('shirt', 'Ashley', 'Fisher', 'Angry Ants', 79),
#  ('shirt', 'Rebecca', 'Peterson', 'Angry Ants', 81),
#  ('shirt', 'Todd', 'Fields', 'Angry Ants', 84),
#  ('shirt', 'Doris', 'Jenkins', 'Angry Ants', 80),
#  ('shirt', 'Sara', 'Morales', 'Angry Ants', 79),
#  ('shirt', 'Fred', 'Walker', 'Angry Ants', 82),
#  ('shirt', 'Raymond', 'Romero', 'Angry Ants', 87),
#  ('shirt', 'Patricia', 'James', 'Angry Ants', 77),
#  ('shirt', 'Dennis', 'Gordon', 'Angry Ants', 84),
#  ('shirt', 'Terry', 'Stanley', 'Angry Ants', 82),
#  ('shirt', 'Emily', 'Gutierrez', 'Angry Ants', 85),
#  ('shirt', 'Paula', 'Williamson', 'Angry Ants', 83),
#  ('shirt', 'Randy', 'Ellis', 'Angry Ants', 78),
#  ('shirt', 'Anne', 'Franklin', 'Angry Ants', 79),
#  ('shirt', 'Daniel', 'Woods', 'Angry Ants', 78),
#  ('shirt', 'Jane', 'Simmons', 'Angry Ants', 80),
#  ('shirt', 'Rose', 'Garcia', 'Angry Ants', 85),
#  ('shirt', 'Walter', 'Andrews', 'Angry Ants', 75),
#  ('shirt', 'Lois', 'Hart', 'Angry Ants', 84),
#  ('shirt', 'Jacqueline', 'Patterson', 'Angry Ants', 88),
#  ('shirt', 'Wanda', 'Perez', 'Angry Ants', 90),
#  ('shirt', 'Irene', 'Gibson', 'Angry Ants', 75),
#  ('shirt', 'Ralph', 'Medina', 'Angry Ants', 76),
#  ('shirt', 'Gerald', 'Wagner', 'Angry Ants', 78),
#  ('shirt', 'Kenneth', 'Campbell', 'Angry Ants', 77),
#  ('shirt', 'Jacqueline', 'Montgomery', 'Angry Ants', 81),
#  ('shirt', 'Maria', 'Martin', 'Angry Ants', 65),
#  ('shirt', 'Harold', 'Gonzales', 'Angry Ants', 85),
#  ('shirt', 'Janet', 'Carroll', 'Angry Ants', 75),
#  ('shirt', 'Wayne', 'Ryan', 'Angry Ants', 82),
#  ('shirt', 'Russell', 'Peterson', 'Angry Ants', 86),
#  ('shirt', 'Joyce', 'Edwards', 'Angry Ants', 83),
#  ('shirt', 'Jimmy', 'Harrison', 'Angry Ants', 77),
#  ('shirt', 'Joshua', 'Green', 'Angry Ants', 79),
#  ('shirt', 'Wanda', 'Hernandez', 'Angry Ants', 84),
#  ('shirt', 'Jeremy', 'Cunningham', 'Angry Ants', 67),
#  ('shirt', 'James', 'Little', 'Angry Ants', 81),
#  ('shirt', 'Ann', 'Gonzales', 'Angry Ants', 86),
#  ('shirt', 'Evelyn', 'Oliver', 'Angry Ants', 79),
#  ('shirt', 'Gerald', 'West', 'Angry Ants', 76),
#  ('shirt', 'Jimmy', 'Carr', 'Angry Ants', 86),
#  ('shirt', 'Rebecca', 'Reed', 'Angry Ants', 82),
#  ('shirt', 'Steve', 'West', 'Angry Ants', 71),
#  ('shirt', 'Christina', 'Lynch', 'Angry Ants', 80),
#  ('shirt', 'Nancy', 'Rivera', 'Angry Ants', 82),
#  ('shirt', 'Christine', 'Reyes', 'Angry Ants', 78),
#  ('shirt', 'Bruce', 'Mills', 'Angry Ants', 86),
#  ('shirt', 'Benjamin', 'Sims', 'Angry Ants', 77),
#  ('shirt', 'Sean', 'Gibson', 'Angry Ants', 86),
#  ('shirt', 'Joyce', 'Wells', 'Angry Ants', 74),
#  ('shirt', 'Shawn', 'Jordan', 'Angry Ants', 82),
#  ('shirt', 'Phillip', 'James', 'Angry Ants', 85),
#  ('shirt', 'Tammy', 'Nichols', 'Angry Ants', 89),
#  ('shirt', 'Todd', 'Lopez', 'Angry Ants', 84),
#  ('shirt', 'Randy', 'Johnston', 'Angry Ants', 88),
#  ('shirt', 'Teresa', 'Day', 'Angry Ants', 86),
#  ('shirt', 'Brian', 'Stevens', 'Angry Ants', 82),
#  ('shirt', 'Martin', 'Simpson', 'Angry Ants', 82),
#  ('shirt', 'Louis', 'Watson', 'Angry Ants', 76),
#  ('shirt', 'Heather', 'Little', 'Angry Ants', 75),
#  ('shirt', 'Gloria', 'Crawford', 'Angry Ants', 83),
#  ('shirt', 'Ann', 'Adams', 'Angry Ants', 75),
#  ('shirt', 'Nicole', 'Chavez', 'Angry Ants', 79),
#  ('shirt', 'Amy', 'Hudson', 'Angry Ants', 85),
#  ('shirt', 'Martha', 'Riley', 'Angry Ants', 79),
#  ('shirt', 'Emily', 'James', 'Angry Ants', 63),
#  ('shirt', 'Steve', 'Pierce', 'Angry Ants', 84),
#  ('shirt', 'Christina', 'Burke', 'Angry Ants', 75),
#  ('shirt', 'Carol', 'Ross', 'Angry Ants', 79),
#  ('shirt', 'Timothy', 'Fernandez', 'Angry Ants', 74),
#  ('shirt', 'Martha', 'Hudson', 'Angry Ants', 76),
#  ('shirt', 'Ann', 'Harrison', 'Angry Ants', 77),
#  ('shirt', 'Donna', 'Hernandez', 'Angry Ants', 80),
#  ('shirt', 'Christine', 'Murray', 'Angry Ants', 81),
#  ('shirt', 'Angela', 'Ford', 'Angry Ants', 84),
#  ('shirt', 'Earl', 'Burns', 'Angry Ants', 81),
#  ('shirt', 'Kelly', 'White', 'Angry Ants', 70),
#  ('shirt', 'Christina', 'Perry', 'Angry Ants', 76),
#  ('shirt', 'Ronald', 'Henry', 'Angry Ants', 76),
#  ('shirt', 'Jimmy', 'Foster', 'Angry Ants', 79),
#  ('shirt', 'Frances', 'Hunter', 'Angry Ants', 87),
#  ('shirt', 'Laura', 'Olson', 'Baffled Badgers', 84),
#  ('shirt', 'Christine', 'Wood', 'Baffled Badgers', 82),
#  ('shirt', 'Jerry', 'Ferguson', 'Baffled Badgers', 81),
#  ('shirt', 'Linda', 'Mitchell', 'Baffled Badgers', 92),
#  ('shirt', 'Robert', 'Hart', 'Baffled Badgers', 89),
#  ('shirt', 'Christina', 'Evans', 'Baffled Badgers', 83),
#  ('shirt', 'Linda', 'Foster', 'Baffled Badgers', 92),
#  ('shirt', 'Barbara', 'Ortiz', 'Baffled Badgers', 87),
#  ('shirt', 'David', 'Ford', 'Baffled Badgers', 84),
#  ('shirt', 'Ann', 'Adams', 'Baffled Badgers', 82),
#  ('shirt', 'Jerry', 'Henderson', 'Baffled Badgers', 84),
#  ('shirt', 'Lawrence', 'Hart', 'Baffled Badgers', 91),
#  ('shirt', 'Laura', 'Brown', 'Baffled Badgers', 82),
#  ('shirt', 'Rose', 'Williams', 'Baffled Badgers', 90),
#  ('shirt', 'Roy', 'Rivera', 'Baffled Badgers', 81),
#  ('shirt', 'Anthony', 'Day', 'Baffled Badgers', 83),
#  ('shirt', 'Kathleen', 'Bryant', 'Baffled Badgers', 87),
#  ('shirt', 'Roy', 'Reid', 'Baffled Badgers', 84),
#  ('shirt', 'Victor', 'Johnson', 'Baffled Badgers', 97),
#  ('shirt', 'Cheryl', 'Myers', 'Baffled Badgers', 94),
#  ('shirt', 'Robin', 'Shaw', 'Baffled Badgers', 90),
#  ('shirt', 'Shawn', 'Thompson', 'Baffled Badgers', 91),
#  ('shirt', 'Ernest', 'Mills', 'Baffled Badgers', 79),
#  ('shirt', 'Joan', 'Wheeler', 'Baffled Badgers', 85),
#  ('shirt', 'Jacqueline', 'Evans', 'Baffled Badgers', 82),
#  ('shirt', 'Irene', 'Perkins', 'Baffled Badgers', 81),
#  ('shirt', 'Tammy', 'Gonzales', 'Baffled Badgers', 92),
#  ('shirt', 'Benjamin', 'Bowman', 'Baffled Badgers', 79),
#  ('shirt', 'Clarence', 'Watson', 'Baffled Badgers', 94),
#  ('shirt', 'Jennifer', 'Medina', 'Baffled Badgers', 92),
#  ('shirt', 'Brian', 'Carter', 'Baffled Badgers', 77),
#  ('shirt', 'Raymond', 'Diaz', 'Baffled Badgers', 86),
#  ('shirt', 'Marilyn', 'Ferguson', 'Baffled Badgers', 87),
#  ('shirt', 'Louis', 'Hanson', 'Baffled Badgers', 78),
#  ('shirt', 'Stephanie', 'Russell', 'Baffled Badgers', 88),
#  ('shirt', 'Henry', 'Burns', 'Baffled Badgers', 84),
#  ('shirt', 'Thomas', 'Stewart', 'Baffled Badgers', 77),
#  ('shirt', 'Willie', 'Elliott', 'Baffled Badgers', 96),
#  ('shirt', 'Annie', 'Richards', 'Baffled Badgers', 79),
#  ('shirt', 'Victor', 'Gray', 'Baffled Badgers', 88),
#  ('shirt', 'Ruth', 'Johnson', 'Baffled Badgers', 80),
#  ('shirt', 'Jeffrey', 'Sanchez', 'Baffled Badgers', 79),
#  ('shirt', 'Mark', 'George', 'Baffled Badgers', 85),
#  ('shirt', 'Frances', 'Barnes', 'Baffled Badgers', 81),
#  ('shirt', 'Antonio', 'Hart', 'Baffled Badgers', 85),
#  ('shirt', 'Jennifer', 'Fowler', 'Baffled Badgers', 84),
#  ('shirt', 'Joseph', 'Howard', 'Baffled Badgers', 84),
#  ('shirt', 'Debra', 'Gonzalez', 'Baffled Badgers', 83),
#  ('shirt', 'Anna', 'Brown', 'Baffled Badgers', 82),
#  ('shirt', 'Wanda', 'Torres', 'Baffled Badgers', 78),
#  ('shirt', 'Bobby', 'Lynch', 'Baffled Badgers', 93),
#  ('shirt', 'Nancy', 'Murphy', 'Baffled Badgers', 88),
#  ('shirt', 'Melissa', 'Franklin', 'Baffled Badgers', 86),
#  ('shirt', 'Emily', 'Marshall', 'Baffled Badgers', 90),
#  ('shirt', 'Sandra', 'Lawrence', 'Baffled Badgers', 81),
#  ('shirt', 'Frank', 'West', 'Baffled Badgers', 79),
#  ('shirt', 'Maria', 'Morgan', 'Baffled Badgers', 78),
#  ('shirt', 'Jacqueline', 'Payne', 'Baffled Badgers', 86),
#  ('shirt', 'Eric', 'Martinez', 'Baffled Badgers', 80),
#  ('shirt', 'Anne', 'Porter', 'Baffled Badgers', 76),
#  ('shirt', 'Jimmy', 'Willis', 'Baffled Badgers', 85),
#  ('shirt', 'Rebecca', 'Murray', 'Baffled Badgers', 85),
#  ('shirt', 'Denise', 'Lawson', 'Baffled Badgers', 87),
#  ('shirt', 'Anna', 'Porter', 'Baffled Badgers', 87),
#  ('shirt', 'Joe', 'Owens', 'Baffled Badgers', 78),
#  ('shirt', 'Judy', 'Armstrong', 'Baffled Badgers', 84),
#  ('shirt', 'Willie', 'Kennedy', 'Baffled Badgers', 77),
#  ('shirt', 'Terry', 'Peters', 'Baffled Badgers', 84),
#  ('shirt', 'Louise', 'Howard', 'Baffled Badgers', 81),
#  ('shirt', 'Laura', 'Lopez', 'Baffled Badgers', 93),
#  ('shirt', 'Teresa', 'Ford', 'Baffled Badgers', 73),
#  ('shirt', 'Jacqueline', 'Rivera', 'Baffled Badgers', 83),
#  ('shirt', 'Christine', 'James', 'Baffled Badgers', 87),
#  ('shirt', 'Maria', 'Harrison', 'Baffled Badgers', 89),
#  ('shirt', 'Frank', 'Gutierrez', 'Baffled Badgers', 85),
#  ('shirt', 'Justin', 'Snyder', 'Baffled Badgers', 88),
#  ('shirt', 'Jeffrey', 'Martinez', 'Baffled Badgers', 87),
#  ('shirt', 'Shawn', 'Spencer', 'Baffled Badgers', 76),
#  ('shirt', 'Earl', 'Watkins', 'Baffled Badgers', 80),
#  ('shirt', 'Sara', 'Lawson', 'Baffled Badgers', 82),
#  ('shirt', 'Joyce', 'Bennett', 'Baffled Badgers', 82),
#  ('shirt', 'Douglas', 'Mills', 'Baffled Badgers', 89),
#  ('shirt', 'Philip', 'Crawford', 'Baffled Badgers', 88),
#  ('shirt', 'Teresa', 'Stephens', 'Baffled Badgers', 85),
#  ('shirt', 'Shawn', 'Hayes', 'Baffled Badgers', 83),
#  ('shirt', 'Teresa', 'Sullivan', 'Baffled Badgers', 80),
#  ('shirt', 'Ruth', 'Alvarez', 'Baffled Badgers', 81),
#  ('shirt', 'Deborah', 'Murray', 'Baffled Badgers', 90),
#  ('shirt', 'Melissa', 'Hunt', 'Baffled Badgers', 91),
#  ('shirt', 'Patrick', 'Barnes', 'Baffled Badgers', 81),
#  ('shirt', 'Denise', 'Fuller', 'Baffled Badgers', 89),
#  ('shirt', 'Kenneth', 'Gomez', 'Baffled Badgers', 84),
#  ('shirt', 'Denise', 'Lawson', 'Baffled Badgers', 86),
#  ('shirt', 'Johnny', 'Wells', 'Baffled Badgers', 91),
#  ('shirt', 'Stephen', 'Hughes', 'Baffled Badgers', 85),
#  ('shirt', 'Louis', 'Stone', 'Baffled Badgers', 94),
#  ('shirt', 'Mark', 'Holmes', 'Baffled Badgers', 72),
#  ('shirt', 'Maria', 'Mitchell', 'Baffled Badgers', 91),
#  ('shirt', 'Ashley', 'Riley', 'Baffled Badgers', 76),
#  ('shirt', 'Ruby', 'Daniels', 'Baffled Badgers', 86),
#  ('shirt', 'Alan', 'Butler', 'Baffled Badgers', 90),
#  ('shirt', 'Debra', 'Garrett', 'Baffled Badgers', 78),
#  ('shirt', 'Louise', 'Stewart', 'Baffled Badgers', 85),
#  ('shirt', 'Judy', 'Andrews', 'Baffled Badgers', 83),
#  ('shirt', 'Craig', 'Ortiz', 'Baffled Badgers', 72),
#  ('shirt', 'Janice', 'Bryant', 'Baffled Badgers', 88),
#  ('shirt', 'Ralph', 'Morales', 'Baffled Badgers', 79),
#  ('shirt', 'Patricia', 'Cooper', 'Baffled Badgers', 92),
#  ('shirt', 'Frank', 'Nguyen', 'Baffled Badgers', 85),
#  ('shirt', 'Julie', 'Bell', 'Baffled Badgers', 99),
#  ('shirt', 'Joe', 'Gray', 'Baffled Badgers', 86),
#  ('shirt', 'Ashley', 'Reid', 'Baffled Badgers', 82),
#  ('shirt', 'Mark', 'Franklin', 'Baffled Badgers', 78),
#  ('shirt', 'Billy', 'Banks', 'Baffled Badgers', 92),
#  ('shirt', 'Jesse', 'Morris', 'Baffled Badgers', 82),
#  ('shirt', 'Carlos', 'Owens', 'Baffled Badgers', 90),
#  ('shirt', 'Thomas', 'Reyes', 'Baffled Badgers', 86),
#  ('shirt', 'Denise', 'Hanson', 'Baffled Badgers', 89),
#  ('shirt', 'Christina', 'Gardner', 'Baffled Badgers', 82),
#  ('shirt', 'Timothy', 'Payne', 'Baffled Badgers', 84),
#  ('shirt', 'Clarence', 'Morales', 'Baffled Badgers', 81),
#  ('shirt', 'Doris', 'Chavez', 'Baffled Badgers', 86),
#  ('shirt', 'Rose', 'Rivera', 'Baffled Badgers', 75),
#  ('shirt', 'Carolyn', 'Kelly', 'Baffled Badgers', 90),
#  ('shirt', 'Gloria', 'Diaz', 'Baffled Badgers', 83),
#  ('shirt', 'Ashley', 'Franklin', 'Baffled Badgers', 91),
#  ('shirt', 'Carl', 'Matthews', 'Baffled Badgers', 81),
#  ('shirt', 'Carol', 'Robinson', 'Baffled Badgers', 77),
#  ('shirt', 'Carl', 'Sanders', 'Baffled Badgers', 82),
#  ('shirt', 'Jeremy', 'Nguyen', 'Baffled Badgers', 87),
#  ('shirt', 'Brenda', 'Brooks', 'Baffled Badgers', 86),
#  ('shirt', 'Frank', 'Hughes', 'Baffled Badgers', 81),
#  ('shirt', 'Richard', 'Stevens', 'Baffled Badgers', 78),
#  ('shirt', 'Laura', 'Mason', 'Baffled Badgers', 87),
#  ('shirt', 'Julie', 'Day', 'Baffled Badgers', 86),
#  ('shirt', 'Brandon', 'Jackson', 'Baffled Badgers', 89),
#  ('shirt', 'Antonio', 'Romero', 'Baffled Badgers', 83),
#  ('shirt', 'Rachel', 'Jackson', 'Baffled Badgers', 88),
#  ('shirt', 'Mary', 'Washington', 'Baffled Badgers', 87),
#  ('shirt', 'Jack', 'Garcia', 'Cosmic Cobras', 98),
#  ('shirt', 'Darren', 'Black', 'Cosmic Cobras', 87),
#  ('shirt', 'Rose', 'Armstrong', 'Cosmic Cobras', 93),
#  ('shirt', 'Robin', 'Hayes', 'Cosmic Cobras', 98),
#  ('shirt', 'Joe', 'Thompson', 'Cosmic Cobras', 96),
#  ('shirt', 'Gary', 'Peters', 'Cosmic Cobras', 97),
#  ('shirt', 'Stephen', 'Jacobs', 'Cosmic Cobras', 95),
#  ('shirt', 'Nicole', 'Banks', 'Cosmic Cobras', 87),
#  ('shirt', 'Brian', 'Palmer', 'Cosmic Cobras', 88),
#  ('shirt', 'Douglas', 'Williamson', 'Cosmic Cobras', 85),
#  ('shirt', 'Billy', 'Marshall', 'Cosmic Cobras', 88),
#  ('shirt', 'Jack', 'Gutierrez', 'Cosmic Cobras', 85),
#  ('shirt', 'Donna', 'Carr', 'Cosmic Cobras', 86),
#  ('shirt', 'Jesse', 'Jenkins', 'Cosmic Cobras', 91),
#  ('shirt', 'James', 'Murray', 'Cosmic Cobras', 97),
#  ('shirt', 'Willie', 'Hudson', 'Cosmic Cobras', 83),
#  ('shirt', 'Lillian', 'King', 'Cosmic Cobras', 84),
#  ('shirt', 'Clarence', 'Reed', 'Cosmic Cobras', 90),
#  ('shirt', 'Jason', 'Lynch', 'Cosmic Cobras', 95),
#  ('shirt', 'Anna', 'Cooper', 'Cosmic Cobras', 96),
#  ('shirt', 'Jonathan', 'Cook', 'Cosmic Cobras', 92),
#  ('shirt', 'Stephanie', 'Martinez', 'Cosmic Cobras', 85),
#  ('shirt', 'Joyce', 'Payne', 'Cosmic Cobras', 87),
#  ('shirt', 'Janet', 'Brooks', 'Cosmic Cobras', 88),
#  ('shirt', 'Martin', 'Murray', 'Cosmic Cobras', 96),
#  ('shirt', 'Harold', 'Patterson', 'Cosmic Cobras', 90),
#  ('shirt', 'Amy', 'Crawford', 'Cosmic Cobras', 94),
#  ('shirt', 'Matthew', 'Castillo', 'Cosmic Cobras', 94),
#  ('shirt', 'Matthew', 'Nichols', 'Cosmic Cobras', 97),
#  ('shirt', 'Jack', 'Dean', 'Cosmic Cobras', 86),
#  ('shirt', 'Pamela', 'Chapman', 'Cosmic Cobras', 87),
#  ('shirt', 'Phillip', 'Dixon', 'Cosmic Cobras', 86),
#  ('shirt', 'Louis', 'Cole', 'Cosmic Cobras', 93),
#  ('shirt', 'Keith', 'Harrison', 'Cosmic Cobras', 80),
#  ('shirt', 'Chris', 'Jenkins', 'Cosmic Cobras', 88),
#  ('shirt', 'Gloria', 'Rogers', 'Cosmic Cobras', 98),
#  ('shirt', 'Daniel', 'Williamson', 'Cosmic Cobras', 97),
#  ('shirt', 'Stephen', 'Howard', 'Cosmic Cobras', 92),
#  ('shirt', 'Earl', 'Green', 'Cosmic Cobras', 100),
#  ('shirt', 'Louis', 'Cole', 'Cosmic Cobras', 98),
#  ('shirt', 'Richard', 'Myers', 'Cosmic Cobras', 94),
#  ('shirt', 'Steve', 'Gomez', 'Cosmic Cobras', 93),
#  ('shirt', 'Cynthia', 'Evans', 'Cosmic Cobras', 93),
#  ('shirt', 'Deborah', 'Hanson', 'Cosmic Cobras', 88),
#  ('shirt', 'Amy', 'Simpson', 'Cosmic Cobras', 90),
#  ('shirt', 'Mary', 'Ruiz', 'Cosmic Cobras', 91),
#  ('shirt', 'Darren', 'Harris', 'Cosmic Cobras', 92),
#  ('shirt', 'Eugene', 'Ray', 'Cosmic Cobras', 89),
#  ('shirt', 'Keith', 'Fox', 'Cosmic Cobras', 92),
#  ('shirt', 'Stephen', 'Snyder', 'Cosmic Cobras', 88),
#  ('shirt', 'Edward', 'Ross', 'Cosmic Cobras', 89),
#  ('shirt', 'Charles', 'Matthews', 'Cosmic Cobras', 94),
#  ('shirt', 'Paula', 'Bishop', 'Cosmic Cobras', 90),
#  ('shirt', 'Linda', 'Gonzalez', 'Cosmic Cobras', 96),
#  ('shirt', 'Jesse', 'Jones', 'Cosmic Cobras', 92),
#  ('shirt', 'Sara', 'Payne', 'Cosmic Cobras', 88),
#  ('shirt', 'Aaron', 'Jacobs', 'Cosmic Cobras', 92),
#  ('shirt', 'Barbara', 'Garza', 'Cosmic Cobras', 90),
#  ('shirt', 'Lori', 'Burke', 'Cosmic Cobras', 86),
#  ('shirt', 'Jimmy', 'Price', 'Cosmic Cobras', 95),
#  ('shirt', 'Margaret', 'Hughes', 'Cosmic Cobras', 89),
#  ('shirt', 'Barbara', 'Hunt', 'Cosmic Cobras', 88),
#  ('shirt', 'Debra', 'Hughes', 'Cosmic Cobras', 85),
#  ('shirt', 'Christina', 'Gibson', 'Cosmic Cobras', 84),
#  ('shirt', 'Phillip', 'Hansen', 'Cosmic Cobras', 92),
#  ('shirt', 'Cheryl', 'Kim', 'Cosmic Cobras', 93),
#  ('shirt', 'Catherine', 'Lewis', 'Cosmic Cobras', 94),
#  ('shirt', 'Russell', 'Jackson', 'Cosmic Cobras', 93),
#  ('shirt', 'Helen', 'Fuller', 'Cosmic Cobras', 93),
#  ('shirt', 'Brandon', 'Hayes', 'Cosmic Cobras', 93),
#  ('shirt', 'Matthew', 'Mendoza', 'Cosmic Cobras', 86),
#  ('shirt', 'Julia', 'Hawkins', 'Cosmic Cobras', 81),
#  ('shirt', 'Carl', 'Boyd', 'Cosmic Cobras', 86),
#  ('shirt', 'Angela', 'Elliott', 'Cosmic Cobras', 87),
#  ('shirt', 'Anna', 'Perkins', 'Cosmic Cobras', 92),
#  ('shirt', 'Joan', 'Young', 'Cosmic Cobras', 81),
#  ('shirt', 'Gerald', 'Shaw', 'Cosmic Cobras', 88),
#  ('shirt', 'Sarah', 'Ryan', 'Cosmic Cobras', 92),
#  ('shirt', 'Margaret', 'Arnold', 'Cosmic Cobras', 92),
#  ('shirt', 'Norma', 'Robertson', 'Cosmic Cobras', 83),
#  ('shirt', 'Alan', 'Wagner', 'Cosmic Cobras', 96),
#  ('shirt', 'Ralph', 'Fisher', 'Cosmic Cobras', 88),
#  ('shirt', 'Benjamin', 'Thompson', 'Cosmic Cobras', 90),
#  ('shirt', 'Victor', 'Owens', 'Cosmic Cobras', 89),
#  ('shirt', 'Michael', 'Wagner', 'Cosmic Cobras', 86),
#  ('shirt', 'Evelyn', 'Peters', 'Cosmic Cobras', 82),
#  ('shirt', 'Eugene', 'Hansen', 'Cosmic Cobras', 90),
#  ('shirt', 'Raymond', 'Stephens', 'Cosmic Cobras', 89),
#  ('shirt', 'Dennis', 'Lopez', 'Cosmic Cobras', 84),
#  ('shirt', 'Frank', 'Grant', 'Cosmic Cobras', 97),
#  ('shirt', 'Kathleen', 'Watson', 'Cosmic Cobras', 88),
#  ('shirt', 'Debra', 'Bennett', 'Cosmic Cobras', 99),
#  ('shirt', 'Brenda', 'Green', 'Cosmic Cobras', 82),
#  ('shirt', 'Jason', 'Knight', 'Cosmic Cobras', 93),
#  ('shirt', 'Andrea', 'Carpenter', 'Cosmic Cobras', 85),
#  ('shirt', 'Roger', 'Hill', 'Cosmic Cobras', 87),
#  ('shirt', 'Aaron', 'Alexander', 'Cosmic Cobras', 84),
#  ('shirt', 'Linda', 'Hanson', 'Cosmic Cobras', 89),
#  ('shirt', 'Brandon', 'Perkins', 'Cosmic Cobras', 95),
#  ('shirt', 'Anna', 'Arnold', 'Cosmic Cobras', 89),
#  ('shirt', 'Helen', 'Stanley', 'Cosmic Cobras', 89),
#  ('shirt', 'Rebecca', 'Hicks', 'Cosmic Cobras', 83),
#  ('shirt', 'Sharon', 'Oliver', 'Cosmic Cobras', 93),
#  ('shirt', 'Ann', 'Moore', 'Cosmic Cobras', 92),
#  ('shirt', 'Betty', 'Welch', 'Cosmic Cobras', 91),
#  ('shirt', 'Janice', 'Bailey', 'Cosmic Cobras', 77),
#  ('shirt', 'Barbara', 'Howard', 'Cosmic Cobras', 89),
#  ('shirt', 'Shirley', 'Payne', 'Cosmic Cobras', 98),
#  ('shirt', 'Randy', 'Washington', 'Cosmic Cobras', 91),
#  ('shirt', 'Earl', 'Jenkins', 'Cosmic Cobras', 91),
#  ('shirt', 'Jennifer', 'Thomas', 'Cosmic Cobras', 85),
#  ('shirt', 'Ronald', 'Nelson', 'Cosmic Cobras', 92),
#  ('shirt', 'Sean', 'Reed', 'Cosmic Cobras', 90),
#  ('shirt', 'Randy', 'Brown', 'Cosmic Cobras', 88),
#  ('shirt', 'Jennifer', 'Cooper', 'Cosmic Cobras', 93),
#  ('shirt', 'Timothy', 'Powell', 'Cosmic Cobras', 91),
#  ('shirt', 'Norma', 'Cunningham', 'Cosmic Cobras', 86),
#  ('shirt', 'Arthur', 'Lawson', 'Cosmic Cobras', 89),
#  ('shirt', 'Bobby', 'Frazier', 'Cosmic Cobras', 90),
#  ('shirt', 'Brian', 'Berry', 'Cosmic Cobras', 91),
#  ('shirt', 'Diane', 'Kelly', 'Cosmic Cobras', 79),
#  ('shirt', 'Russell', 'Stephens', 'Cosmic Cobras', 82),
#  ('shirt', 'Eric', 'Nguyen', 'Cosmic Cobras', 97),
#  ('shirt', 'Harry', 'Jones', 'Cosmic Cobras', 90),
#  ('shirt', 'Jason', 'Mitchell', 'Cosmic Cobras', 87),
#  ('shirt', 'Michael', 'Gonzalez', 'Cosmic Cobras', 85),
#  ('shirt', 'Walter', 'Burns', 'Cosmic Cobras', 94),
#  ('shirt', 'Martha', 'Perez', 'Cosmic Cobras', 80),
#  ('shirt', 'Carlos', 'Hanson', 'Cosmic Cobras', 89),
#  ('shirt', 'Frances', 'Miller', 'Cosmic Cobras', 84),
#  ('shirt', 'Bonnie', 'Willis', 'Cosmic Cobras', 91),
#  ('shirt', 'Frances', 'Austin', 'Cosmic Cobras', 96),
#  ('shirt', 'Charles', 'Edwards', 'Cosmic Cobras', 82),
#  ('shirt', 'Diane', 'Perry', 'Cosmic Cobras', 84),
#  ('shirt', 'Daniel', 'Alvarez', 'Cosmic Cobras', 88),
#  ('shirt', 'Stephen', 'Wagner', 'Cosmic Cobras', 91),
#  ('shirt', 'Stephanie', 'Stevens', 'Cosmic Cobras', 83),
#  ('shirt', 'William', 'Fernandez', 'Cosmic Cobras', 86),
#  ('shirt', 'Alice', 'Roberts', 'Cosmic Cobras', 89),
#  ('shirt', 'Catherine', 'Anderson', 'Cosmic Cobras', 95),
#  ('shirt', 'Randy', 'Cox', 'Cosmic Cobras', 87),
#  ('shirt', 'Andrew', 'Baker', 'Cosmic Cobras', 92),
#  ('shirt', 'Fred', 'Lane', 'Cosmic Cobras', 89),
#  ('shirt', 'Peter', 'Snyder', 'Cosmic Cobras', 91),
#  ('shirt', 'Julie', 'Turner', 'Cosmic Cobras', 85),
#  ('shirt', 'Nancy', 'Roberts', 'Cosmic Cobras', 81)]

# %% [markdown]
# ### Ask for Data from Two or More Tables

# %%
# %%sql
#
# /*
#  * Create a summary of how many hats need to be shipped to each state
#  * Create a summary showing how many members of each team are in each
#     geographic division
# */
#
# SELECT s.state_name, COUNT(p.shirt_or_hat) hat_count
# FROM states s
# JOIN people p ON s.state_abbrev =  p.state_code
# WHERE p.shirt_or_hat == 'hat'
# GROUP BY p.shirt_or_hat, s.state_name;
# Out:
#  * sqlite:///quizdata.db
# Done.
# [('Alabama', 14),
#  ('Arizona', 10),
#  ('Arkansas', 4),
#  ('California', 73),
#  ('Colorado', 17),
#  ('Connecticut', 8),
#  ('Florida', 53),
#  ('Georgia', 15),
#  ('Idaho', 3),
#  ('Illinois', 8),
#  ('Indiana', 17),
#  ('Iowa', 3),
#  ('Kansas', 12),
#  ('Kentucky', 10),
#  ('Louisiana', 10),
#  ('Maryland', 8),
#  ('Massachusetts', 11),
#  ('Michigan', 7),
#  ('Minnesota', 10),
#  ('Mississippi', 3),
#  ('Missouri', 16),
#  ('Montana', 3),
#  ('Nebraska', 4),
#  ('Nevada', 8),
#  ('New Hampshire', 1),
#  ('New Jersey', 4),
#  ('New Mexico', 3),
#  ('New York', 43),
#  ('North Carolina', 17),
#  ('North Dakota', 1),
#  ('Ohio', 19),
#  ('Oklahoma', 8),
#  ('Oregon', 3),
#  ('Pennsylvania', 20),
#  ('South Carolina', 7),
#  ('South Dakota', 2),
#  ('Tennessee', 10),
#  ('Texas', 54),
#  ('Utah', 3),
#  ('Vermont', 1),
#  ('Virginia', 26),
#  ('Washington', 13),
#  ('West Virginia', 3),
#  ('Wisconsin', 5)]

# %%
# %%sql
#
# /*
#  * Create a summary of how many hats need to be shipped to each state
#  * Create a summary showing how many members of each team are in each
#     geographic division
# */
#
# SELECT s.state_name, COUNT(p.shirt_or_hat) hat_count
# FROM states s
# JOIN people p ON s.state_abbrev =  p.state_code
# GROUP BY p.shirt_or_hat, s.state_name
# HAVING p.shirt_or_hat == 'hat';
# Out:
#  * sqlite:///quizdata.db
# Done.
# [('Alabama', 14),
#  ('Arizona', 10),
#  ('Arkansas', 4),
#  ('California', 73),
#  ('Colorado', 17),
#  ('Connecticut', 8),
#  ('Florida', 53),
#  ('Georgia', 15),
#  ('Idaho', 3),
#  ('Illinois', 8),
#  ('Indiana', 17),
#  ('Iowa', 3),
#  ('Kansas', 12),
#  ('Kentucky', 10),
#  ('Louisiana', 10),
#  ('Maryland', 8),
#  ('Massachusetts', 11),
#  ('Michigan', 7),
#  ('Minnesota', 10),
#  ('Mississippi', 3),
#  ('Missouri', 16),
#  ('Montana', 3),
#  ('Nebraska', 4),
#  ('Nevada', 8),
#  ('New Hampshire', 1),
#  ('New Jersey', 4),
#  ('New Mexico', 3),
#  ('New York', 43),
#  ('North Carolina', 17),
#  ('North Dakota', 1),
#  ('Ohio', 19),
#  ('Oklahoma', 8),
#  ('Oregon', 3),
#  ('Pennsylvania', 20),
#  ('South Carolina', 7),
#  ('South Dakota', 2),
#  ('Tennessee', 10),
#  ('Texas', 54),
#  ('Utah', 3),
#  ('Vermont', 1),
#  ('Virginia', 26),
#  ('Washington', 13),
#  ('West Virginia', 3),
#  ('Wisconsin', 5)]

# %%
# %%sql
#
# /*
#  * Create a summary of how many hats need to be shipped to each state
#  * Create a summary showing how many members of each team are in each
#     geographic division
# */
#
# SELECT s.state_name, sub.hat_count
# FROM states s
# LEFT JOIN
# 	(SELECT s.state_name, COUNT(p.shirt_or_hat) hat_count
# 	FROM states s
# 	JOIN people p ON s.state_abbrev =  p.state_code
# 	GROUP BY p.shirt_or_hat, s.state_name
# 	HAVING p.shirt_or_hat == 'hat')  sub
# ON s.state_name = sub.state_name;
# Out:
#  * sqlite:///quizdata.db
# Done.
# [('Alabama', 14),
#  ('Alaska', None),
#  ('Arizona', 10),
#  ('Arkansas', 4),
#  ('California', 73),
#  ('Colorado', 17),
#  ('Connecticut', 8),
#  ('Delaware', None),
#  ('Florida', 53),
#  ('Georgia', 15),
#  ('Hawaii', None),
#  ('Idaho', 3),
#  ('Illinois', 8),
#  ('Indiana', 17),
#  ('Iowa', 3),
#  ('Kansas', 12),
#  ('Kentucky', 10),
#  ('Louisiana', 10),
#  ('Maine', None),
#  ('Maryland', 8),
#  ('Massachusetts', 11),
#  ('Michigan', 7),
#  ('Minnesota', 10),
#  ('Mississippi', 3),
#  ('Missouri', 16),
#  ('Montana', 3),
#  ('Nebraska', 4),
#  ('Nevada', 8),
#  ('New Hampshire', 1),
#  ('New Jersey', 4),
#  ('New Mexico', 3),
#  ('New York', 43),
#  ('North Carolina', 17),
#  ('North Dakota', 1),
#  ('Ohio', 19),
#  ('Oklahoma', 8),
#  ('Oregon', 3),
#  ('Pennsylvania', 20),
#  ('Rhode Island', None),
#  ('South Carolina', 7),
#  ('South Dakota', 2),
#  ('Tennessee', 10),
#  ('Texas', 54),
#  ('Utah', 3),
#  ('Vermont', 1),
#  ('Virginia', 26),
#  ('Washington', 13),
#  ('West Virginia', 3),
#  ('Wisconsin', 5),
#  ('Wyoming', None)]

# %%
# %%sql
#
# /*
#  * Create a summary of how many hats need to be shipped to each state
#  * Create a summary showing how many members of each team are in each
#     geographic division
# */
#
# WITH hat_counts AS (SELECT s.state_name, COUNT(p.shirt_or_hat) hat_count
# 	FROM states s
# 	JOIN people p ON s.state_abbrev =  p.state_code
# 	GROUP BY p.shirt_or_hat, s.state_name
# 	HAVING p.shirt_or_hat == 'hat')
#
# SELECT s.state_name,
# 	CASE WHEN h.hat_count IS NULL THEN 0
# 	ELSE h.hat_count
# 	END AS hat_count
# FROM states s
# LEFT JOIN
# 	hat_counts h
# ON s.state_name = h.state_name;
# Out:
#  * sqlite:///quizdata.db
# Done.
# [('Alabama', 14),
#  ('Alaska', 0),
#  ('Arizona', 10),
#  ('Arkansas', 4),
#  ('California', 73),
#  ('Colorado', 17),
#  ('Connecticut', 8),
#  ('Delaware', 0),
#  ('Florida', 53),
#  ('Georgia', 15),
#  ('Hawaii', 0),
#  ('Idaho', 3),
#  ('Illinois', 8),
#  ('Indiana', 17),
#  ('Iowa', 3),
#  ('Kansas', 12),
#  ('Kentucky', 10),
#  ('Louisiana', 10),
#  ('Maine', 0),
#  ('Maryland', 8),
#  ('Massachusetts', 11),
#  ('Michigan', 7),
#  ('Minnesota', 10),
#  ('Mississippi', 3),
#  ('Missouri', 16),
#  ('Montana', 3),
#  ('Nebraska', 4),
#  ('Nevada', 8),
#  ('New Hampshire', 1),
#  ('New Jersey', 4),
#  ('New Mexico', 3),
#  ('New York', 43),
#  ('North Carolina', 17),
#  ('North Dakota', 1),
#  ('Ohio', 19),
#  ('Oklahoma', 8),
#  ('Oregon', 3),
#  ('Pennsylvania', 20),
#  ('Rhode Island', 0),
#  ('South Carolina', 7),
#  ('South Dakota', 2),
#  ('Tennessee', 10),
#  ('Texas', 54),
#  ('Utah', 3),
#  ('Vermont', 1),
#  ('Virginia', 26),
#  ('Washington', 13),
#  ('West Virginia', 3),
#  ('Wisconsin', 5),
#  ('Wyoming', 0)]

# %%
# %%sql
#
# /*
#  * Create a summary of how many hats need to be shipped to each state
#  * Create a summary showing how many members of each team are in each
#     geographic division
# */
#
# SELECT p.team, s.division, COUNT(p.team) team_count
# FROM people p
# JOIN states s ON p.state_code = s.state_abbrev
# GROUP BY p.team, s.division;
# Out:
#  * sqlite:///quizdata.db
# Done.
# [('Angry Ants', 'East North Central', 28),
#  ('Angry Ants', 'East South Central', 22),
#  ('Angry Ants', 'Middle Atlantic', 27),
#  ('Angry Ants', 'Mountain', 27),
#  ('Angry Ants', 'New England', 15),
#  ('Angry Ants', 'Pacific', 48),
#  ('Angry Ants', 'South Atlantic', 90),
#  ('Angry Ants', 'West North Central', 25),
#  ('Angry Ants', 'West South Central', 51),
#  ('Baffled Badgers', 'East North Central', 40),
#  ('Baffled Badgers', 'East South Central', 12),
#  ('Baffled Badgers', 'Middle Atlantic', 38),
#  ('Baffled Badgers', 'Mountain', 32),
#  ('Baffled Badgers', 'New England', 11),
#  ('Baffled Badgers', 'Pacific', 57),
#  ('Baffled Badgers', 'South Atlantic', 69),
#  ('Baffled Badgers', 'West North Central', 32),
#  ('Baffled Badgers', 'West South Central', 42),
#  ('Cosmic Cobras', 'East North Central', 45),
#  ('Cosmic Cobras', 'East South Central', 26),
#  ('Cosmic Cobras', 'Middle Atlantic', 34),
#  ('Cosmic Cobras', 'Mountain', 21),
#  ('Cosmic Cobras', 'New England', 8),
#  ('Cosmic Cobras', 'Pacific', 56),
#  ('Cosmic Cobras', 'South Atlantic', 69),
#  ('Cosmic Cobras', 'West North Central', 25),
#  ('Cosmic Cobras', 'West South Central', 50)]

# %% [markdown]
# ### Data Types, Math, and Helpful Features

# %%
# %%sql
#
# /*
#  * Show maximum score and average score in each state
#  * Sort by average score, with the largest at the top of the report
# */
#
# SELECT state_code, MAX(quiz_points) max_score, AVG(quiz_points) average_score
# FROM people
# GROUP BY state_code
# ORDER BY average_score DESC;
# Out:
#  * sqlite:///quizdata.db
# Done.
# [('AK', 93, 93.0),
#  ('IL', 98, 87.26315789473684),
#  ('SD', 91, 87.25),
#  ('NV', 97, 87.16666666666667),
#  ('WV', 94, 86.66666666666667),
#  ('TN', 100, 86.625),
#  ('SC', 96, 86.33333333333333),
#  ('WA', 100, 86.15789473684211),
#  ('NY', 100, 85.91935483870968),
#  ('AR', 90, 85.83333333333333),
#  ('IN', 97, 85.74074074074075),
#  ('WI', 94, 85.5),
#  ('CO', 98, 85.42857142857143),
#  ('OH', 97, 85.34210526315789),
#  ('IA', 100, 85.33333333333333),
#  ('PA', 94, 85.13333333333334),
#  ('MN', 98, 85.05263157894737),
#  ('AL', 94, 84.95833333333333),
#  ('NE', 93, 84.875),
#  ('OK', 93, 84.85714285714286),
#  ('FL', 99, 84.76344086021506),
#  ('TX', 97, 84.74757281553399),
#  ('CA', 98, 84.4724409448819),
#  ('NC', 99, 84.46428571428571),
#  ('MI', 96, 84.42105263157895),
#  ('AZ', 94, 84.3157894736842),
#  ('UT', 90, 84.28571428571429),
#  ('KS', 100, 84.25),
#  ('MO', 100, 83.66666666666667),
#  ('KY', 93, 83.53333333333333),
#  ('VA', 97, 83.38095238095238),
#  ('NM', 92, 83.0),
#  ('CT', 96, 82.85714285714286),
#  ('LA', 97, 82.8),
#  ('HI', 94, 82.33333333333333),
#  ('GA', 96, 82.33333333333333),
#  ('VT', 82, 82.0),
#  ('MA', 94, 82.0),
#  ('OR', 92, 81.63636363636364),
#  ('NJ', 93, 81.57142857142857),
#  ('MT', 85, 81.33333333333333),
#  ('MD', 95, 81.2),
#  ('ID', 88, 81.2),
#  ('MS', 84, 81.0),
#  ('DE', 84, 80.5),
#  ('ND', 83, 77.5),
#  ('NH', 70, 70.0)]

# %%
# %%sql
#
# /*
#  * Show maximum score and average score in each state
#  * Sort by average score, with the largest at the top of the report
# */
#
# WITH scores AS (SELECT state_code, MAX(quiz_points) max_score, AVG(quiz_points) average_score
# 	FROM people
# 	GROUP BY state_code)
#
# SELECT state_abbrev, sc.max_score max_score, sc.average_score average_score
# FROM states st
# LEFT JOIN scores sc ON st.state_abbrev = sc.state_code
# ORDER BY average_score DESC;
# Out:
#  * sqlite:///quizdata.db
# Done.
# [('AK', 93, 93.0),
#  ('IL', 98, 87.26315789473684),
#  ('SD', 91, 87.25),
#  ('NV', 97, 87.16666666666667),
#  ('WV', 94, 86.66666666666667),
#  ('TN', 100, 86.625),
#  ('SC', 96, 86.33333333333333),
#  ('WA', 100, 86.15789473684211),
#  ('NY', 100, 85.91935483870968),
#  ('AR', 90, 85.83333333333333),
#  ('IN', 97, 85.74074074074075),
#  ('WI', 94, 85.5),
#  ('CO', 98, 85.42857142857143),
#  ('OH', 97, 85.34210526315789),
#  ('IA', 100, 85.33333333333333),
#  ('PA', 94, 85.13333333333334),
#  ('MN', 98, 85.05263157894737),
#  ('AL', 94, 84.95833333333333),
#  ('NE', 93, 84.875),
#  ('OK', 93, 84.85714285714286),
#  ('FL', 99, 84.76344086021506),
#  ('TX', 97, 84.74757281553399),
#  ('CA', 98, 84.4724409448819),
#  ('NC', 99, 84.46428571428571),
#  ('MI', 96, 84.42105263157895),
#  ('AZ', 94, 84.3157894736842),
#  ('UT', 90, 84.28571428571429),
#  ('KS', 100, 84.25),
#  ('MO', 100, 83.66666666666667),
#  ('KY', 93, 83.53333333333333),
#  ('VA', 97, 83.38095238095238),
#  ('NM', 92, 83.0),
#  ('CT', 96, 82.85714285714286),
#  ('LA', 97, 82.8),
#  ('GA', 96, 82.33333333333333),
#  ('HI', 94, 82.33333333333333),
#  ('MA', 94, 82.0),
#  ('VT', 82, 82.0),
#  ('OR', 92, 81.63636363636364),
#  ('NJ', 93, 81.57142857142857),
#  ('MT', 85, 81.33333333333333),
#  ('ID', 88, 81.2),
#  ('MD', 95, 81.2),
#  ('MS', 84, 81.0),
#  ('DE', 84, 80.5),
#  ('ND', 83, 77.5),
#  ('NH', 70, 70.0),
#  ('ME', None, None),
#  ('RI', None, None),
#  ('WY', None, None)]
